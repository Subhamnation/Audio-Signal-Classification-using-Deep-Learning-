# %% [markdown]
# # Feature Extraction
# ## Compute RMS (Root-Mean-Square)
#
# - Compute root-mean-square (RMS) value for each frame, either from the audio samples y or from a spectrogram S.

# %%
import librosa
import IPython.display as ipd
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from sklearn.preprocessing import minmax_scale

# %%
wave_x, sample_rate = librosa.load(librosa.ex('trumpet'))

# %%
ipd.Audio(wave_x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave_x.shape
# Out:
# (117601,)

# %%
rms_values = librosa.feature.rms(y=wave_x)

# %%
rms_values.shape
# Out:
# (1, 230)

# %%
from librosa.feature import rms
import numpy as np

# %%
S, phase = librosa.magphase(librosa.stft(wave_x))
rms = librosa.feature.rms(S=S)

# %%
rms.shape
# Out:
# (1, 230)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, figsize=(20, 10), sharex=True)
times = librosa.times_like(rms)
ax[0].semilogy(times, rms[0], label='RMS Energy')
ax[0].set(xticks=[])
ax[0].legend()
ax[0].label_outer()
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time', ax=ax[1])
ax[1].set(title='log Power spectrogram')
# Out:
# [Text(0.5, 1.0, 'log Power spectrogram')]

# %%
ipd.Audio(wave_x, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave_x, sample_rate = librosa.load(librosa.ex('brahms'))

# %%
S, phase = librosa.magphase(librosa.stft(wave_x))
rms = librosa.feature.rms(S=S)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, figsize=(20, 10), sharex=True)
times = librosa.times_like(rms)
ax[0].semilogy(times, rms[0], label='RMS Energy')
ax[0].set(xticks=[])
ax[0].legend()
ax[0].label_outer()
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time', ax=ax[1])
ax[1].set(title='log Power spectrogram')
# Out:
# [Text(0.5, 1.0, 'log Power spectrogram')]

# %%
wave_x, sample_rate = librosa.load(librosa.ex('humpback'))

S, phase = librosa.magphase(librosa.stft(wave_x))
rms = librosa.feature.rms(S=S)

import matplotlib.pyplot as plt
fig, ax = plt.subplots(nrows=2, figsize=(20, 10), sharex=True)
times = librosa.times_like(rms)
ax[0].semilogy(times, rms[0], label='RMS Energy')
ax[0].set(xticks=[])
ax[0].legend()
ax[0].label_outer()
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time', ax=ax[1])
ax[1].set(title='log Power spectrogram')
# Out:
# [Text(0.5, 1.0, 'log Power spectrogram')]
