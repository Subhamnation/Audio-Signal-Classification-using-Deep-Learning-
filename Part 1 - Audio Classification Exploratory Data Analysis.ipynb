# %% [markdown]
# ### Audio Classification Using Machine Learning

# %%
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
# !pip install librosa
# Out:
# ...
#    ---------------------------------------- 0.0/260.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/260.1 kB ? eta -:--:--
#    - -------------------------------------- 10.2/260.1 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/260.1 kB 262.6 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/260.1 kB 281.8 kB/s eta 0:00:01
#    ---------- ---------------------------- 71.7/260.1 kB 328.6 kB/s eta 0:00:01
#    ------------- ------------------------- 92.2/260.1 kB 403.5 kB/s eta 0:00:01
#    ----------------- -------------------- 122.9/260.1 kB 423.5 kB/s eta 0:00:01
#    ---------------------- --------------- 153.6/260.1 kB 459.5 kB/s eta 0:00:01
#    ---------------------------- --------- 194.6/260.1 kB 491.5 kB/s eta 0:00:01
#    -------------------------------- ----- 225.3/260.1 kB 509.6 kB/s eta 0:00:01
#    ----------------------------------- -- 245.8/260.1 kB 538.9 kB/s eta 0:00:01
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename='E:/courses/resume_projects/Audio Signal Classification using Deep Learning/UrbanSound8K/UrbanSound8K/audio/fold3/12647-3-2-0.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
# !dir
# Out:
#  Volume in drive E has no label.
#  Volume Serial Number is 9C46-A242
#
#  Directory of E:\courses\resume_projects\Audio Signal Classification using Deep Learning
#
# 08-11-2024  15:15    <DIR>          .
# 22-08-2024  16:47    <DIR>          ..
# 08-11-2024  15:09    <DIR>          .ipynb_checkpoints
# 08-11-2024  15:15         1,054,067 Audio Classification EDA.ipynb
# 22-08-2024  16:50         4,705,796 Guide to Audio Classification Using Deep Learning.pdf
# 22-08-2024  16:46           151,197 Part 2- Audio Classification Data Preprocessing And Model Creation.ipynb
# 22-08-2024  16:46           146,754 Part 2- Audio Classification Data Preprocessing.ipynb
# 08-11-2024  15:10    <DIR>          UrbanSound8K
# 22-08-2024  18:12     6,023,741,708 UrbanSound8K.tar.gz
# 22-08-2024  17:05         1,703,264 Using deep learning for audio classification of urban8k dataset based on the Mel-Frequency Cepstral Coefficients(MFCC) from the audio samples. _ by Ujjawal shah _ Medium.pdf
# ...

# %%
### Dog Sound
plt.figure(figsize=(14,5))
plt.title("Dog Barking Sound")
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate) # new version waveplot is changed into waveshow
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
### Car horn Sound
filename='E:/courses/resume_projects/Audio Signal Classification using Deep Learning/UrbanSound8K/UrbanSound8K/audio/fold3/9674-1-0-1.wav'
plt.figure(figsize=(14,5))
plt.title("Car Horn Sound")
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[  -100,    553],
#        [  -144,    745],
#        [   -97,    939],
#        ...,
#        [ -2099,   4724],
#        [ -6223,    -46],
#        [-10405,  -4633]], dtype=int16)

# %%
data #Data visualization using librosa
# Out:
# array([ 0.00529182,  0.01351791,  0.02534325, ...,  0.25949252,
#         0.1551693 , -0.11638264], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv('E:/courses/resume_projects/Audio Signal Classification using Deep Learning/UrbanSound8K/UrbanSound8K/metadata/UrbanSound8K.csv')
#E:\courses\resume_projects\Audio Signal Classification using Deep Learning\UrbanSound8K\UrbanSound8K\metadata
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# ...

# %%
metadata.shape
# Out:
# (8732, 8)

# %%
### Check whether the dataset is imbalanced
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64

# %% [markdown]
# ### Conclusion:
#
# #### In this dataset, most of the categories have all the values available. So, it is a balanced dataset
